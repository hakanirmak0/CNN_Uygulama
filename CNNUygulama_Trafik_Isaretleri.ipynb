# %% [markdown]
# # 1. Google Colab Bağlantıları
#
# Kaynak: https://medium.com/deep-learning-turkiye/google-colab-ile-%C3%BCcretsiz-gpu-kullan%C4%B1m%C4%B1-30fdb7dd822e

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144465 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.22-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
import sys
sys.path.insert(0, 'drive/uygulama')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# #2. Kütüphanelerin Kurulumu

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from random import randint
from keras.utils.np_utils import to_categorical
import tensorflow.keras.models as Models
import tensorflow.keras.layers as Layers
import tensorflow.keras.optimizers as Optimizer
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #3. Verinin Yüklenmesi ve Veri Ön İşleme

# %%
data = pd.read_pickle(r'/content/drive/My Drive/Colab Notebooks/data0.pickle')

# y_train, y_test ve y_validation verilerini keras da kullanabilmek için ön işlem.
data['y_train'] = to_categorical(data['y_train'], num_classes=43)
data['y_validation'] = to_categorical(data['y_validation'], num_classes=43)
data['y_test'] = to_categorical(data['y_test'], num_classes=43)

# Boyutlardaki fotoğrafın kanal değerlerini sona gelecek şekilde düzenlenmesi.
data['x_train'] = data['x_train'].transpose(0, 2, 3, 1)
data['x_validation'] = data['x_validation'].transpose(0, 2, 3, 1)
data['x_test'] = data['x_test'].transpose(0, 2, 3, 1)

# %%
for i, j in data.items():
    if i == 'labels':
        print(i + ':', len(j))
    else: 
        print(i + ':', j.shape)
# Out:
# x_test: (12630, 32, 32, 3)
# y_validation: (4410, 43)
# x_validation: (4410, 32, 32, 3)
# labels: 43
# x_train: (86989, 32, 32, 3)
# y_test: (12630, 43)
# y_train: (86989, 43)

# %% [markdown]
# #4. Veri Görselleştirme

# %%
f,ax = plt.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0, len(data["x_train"]))
        ax[i,j].imshow(data["x_train"][rnd_number])
        ax[i,j].axis('off')

# %% [markdown]
# #5. CNN Modelinin Kurulması

# %%
model = Models.Sequential()

model.add(Layers.Conv2D(200, kernel_size = (3,3), padding="same", activation='relu', input_shape=(32, 32, 3)))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180, kernel_size=(3,3), padding = "same", activation = 'relu'))
model.add(Layers.Conv2D(140, kernel_size=(3,3), padding = "same",activation = 'relu'))
model.add(Layers.Conv2D(100, kernel_size=(3,3), padding = "same",activation = 'relu'))
model.add(Layers.Conv2D(50, kernel_size=(3,3), padding = "same",activation = 'relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180, activation='relu'))
model.add(Layers.Dense(100, activation='relu'))
model.add(Layers.Dense(50, activation='relu'))
model.add(Layers.Dropout(rate = 0.5))
model.add(Layers.Dense(43, activation = 'softmax'))

model.compile(optimizer = Optimizer.Adam(lr = 0.0001), loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 200)       5600
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 6, 6, 200)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 6, 6, 180)         324180
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 6, 140)         226940
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 100)         126100
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 50)          45050
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 50)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 180)               9180
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               18100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                2193
# =================================================================
# Total params: 762,393
# Trainable params: 762,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5.1. Modelin Eğitilmesi

# %%
trained = model.fit(data["x_train"], data["y_train"], batch_size = 256, epochs=35, validation_data = (data['x_validation'], data['y_validation']))
# Out:
# Epoch 1/35
# 340/340 [==============================] - 10s 30ms/step - loss: 3.4478 - accuracy: 0.1087 - val_loss: 2.7153 - val_accuracy: 0.2912
# Epoch 2/35
# 340/340 [==============================] - 9s 27ms/step - loss: 2.5550 - accuracy: 0.3156 - val_loss: 1.8128 - val_accuracy: 0.5283
# Epoch 3/35
# 340/340 [==============================] - 9s 27ms/step - loss: 1.8456 - accuracy: 0.4915 - val_loss: 1.3172 - val_accuracy: 0.6685
# Epoch 4/35
# 340/340 [==============================] - 9s 28ms/step - loss: 1.3767 - accuracy: 0.6089 - val_loss: 1.0495 - val_accuracy: 0.7299
# Epoch 5/35
# 340/340 [==============================] - 9s 28ms/step - loss: 1.0771 - accuracy: 0.6887 - val_loss: 0.8267 - val_accuracy: 0.7751
# Epoch 6/35
# 340/340 [==============================] - 9s 28ms/step - loss: 0.8632 - accuracy: 0.7479 - val_loss: 0.7766 - val_accuracy: 0.8032
# Epoch 7/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.7218 - accuracy: 0.7878 - val_loss: 0.7085 - val_accuracy: 0.8220
# Epoch 8/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.6074 - accuracy: 0.8217 - val_loss: 0.7075 - val_accuracy: 0.8404
# Epoch 9/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.5175 - accuracy: 0.8486 - val_loss: 0.5715 - val_accuracy: 0.8537
# Epoch 10/35
# 340/340 [==============================] - 10s 29ms/step - loss: 0.4486 - accuracy: 0.8665 - val_loss: 0.5398 - val_accuracy: 0.8707
# Epoch 11/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.3961 - accuracy: 0.8815 - val_loss: 0.5879 - val_accuracy: 0.8821
# Epoch 12/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.3539 - accuracy: 0.8944 - val_loss: 0.5154 - val_accuracy: 0.8769
# Epoch 13/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.3175 - accuracy: 0.9049 - val_loss: 0.6117 - val_accuracy: 0.8753
# Epoch 14/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.2839 - accuracy: 0.9154 - val_loss: 0.5785 - val_accuracy: 0.8866
# Epoch 15/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.2613 - accuracy: 0.9205 - val_loss: 0.5150 - val_accuracy: 0.8859
# Epoch 16/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.2390 - accuracy: 0.9274 - val_loss: 0.5411 - val_accuracy: 0.8930
# Epoch 17/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.2207 - accuracy: 0.9335 - val_loss: 0.5314 - val_accuracy: 0.8937
# Epoch 18/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.2020 - accuracy: 0.9381 - val_loss: 0.5382 - val_accuracy: 0.8977
# Epoch 19/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1906 - accuracy: 0.9414 - val_loss: 0.5001 - val_accuracy: 0.9175
# Epoch 20/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1761 - accuracy: 0.9452 - val_loss: 0.4927 - val_accuracy: 0.9088
# Epoch 21/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1581 - accuracy: 0.9513 - val_loss: 0.6583 - val_accuracy: 0.9066
# Epoch 22/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1595 - accuracy: 0.9494 - val_loss: 0.5303 - val_accuracy: 0.9020
# Epoch 23/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1505 - accuracy: 0.9534 - val_loss: 0.6470 - val_accuracy: 0.8995
# Epoch 24/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1470 - accuracy: 0.9544 - val_loss: 0.5460 - val_accuracy: 0.9098
# Epoch 25/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1261 - accuracy: 0.9605 - val_loss: 0.6358 - val_accuracy: 0.9113
# Epoch 26/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1226 - accuracy: 0.9612 - val_loss: 0.6562 - val_accuracy: 0.9122
# Epoch 27/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1207 - accuracy: 0.9618 - val_loss: 0.5745 - val_accuracy: 0.9177
# Epoch 28/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.1169 - accuracy: 0.9631 - val_loss: 0.6796 - val_accuracy: 0.9122
# Epoch 29/35
# 340/340 [==============================] - 10s 29ms/step - loss: 0.1102 - accuracy: 0.9651 - val_loss: 0.6101 - val_accuracy: 0.9202
# Epoch 30/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.0991 - accuracy: 0.9682 - val_loss: 0.6469 - val_accuracy: 0.9170
# Epoch 31/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.0982 - accuracy: 0.9687 - val_loss: 0.5910 - val_accuracy: 0.9172
# Epoch 32/35
# 340/340 [==============================] - 10s 29ms/step - loss: 0.1006 - accuracy: 0.9684 - val_loss: 0.6284 - val_accuracy: 0.9195
# Epoch 33/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.0894 - accuracy: 0.9714 - val_loss: 0.6464 - val_accuracy: 0.9084
# Epoch 34/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.0853 - accuracy: 0.9727 - val_loss: 0.5644 - val_accuracy: 0.9254
# Epoch 35/35
# 340/340 [==============================] - 10s 28ms/step - loss: 0.0956 - accuracy: 0.9696 - val_loss: 0.7441 - val_accuracy: 0.9045

# %% [markdown]
# ##5.2. Sonuçların Görselleştirilmesi

# %%
plt.plot(trained.history['accuracy'])
plt.plot(trained.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(trained.history['loss'])
plt.plot(trained.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##5.2. Test Verileri ile Modeli Değerlendirme

# %%
model.evaluate(data["x_test"], data["y_test"], verbose=1)
# Out:
# 395/395 [==============================] - 1s 4ms/step - loss: 0.6473 - accuracy: 0.9056
# [0.647260308265686, 0.9056215286254883]
